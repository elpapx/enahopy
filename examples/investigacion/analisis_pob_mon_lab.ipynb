# %%
import importlib
import analisis_pob_mon_lab
importlib.reload((analisis_pob_mon_lab))
# Out:
# <module 'analisis_pob_mon_lab' from 'E:\\papx\\end_to_end_ml\\nb_pr\\enahopy\\examples\\investigacion\\analisis_pob_mon_lab.py'>

# %%
# Instalación (si es necesario)
# !pip install enahopy


import enahopy


# ========== USANDO ENAHOPY ENAHO LOADER ==========
from enahopy.loader import ENAHODataDownloader
from enahopy.loader.io import ENAHOLocalReader


# ========== USANDO ENAHOPY's ENAHOModuleMerger ==========
from enahopy.merger import ENAHOModuleMerger
from enahopy.merger.config import ModuleMergeConfig, ModuleMergeLevel
import logging


# ========== USANDO ENAHOPY ENAHO NULL_ANALYSIS ==========
from enahopy.null_analysis import ENAHONullAnalyzer

import pandas as pd
import numpy as np
from datetime import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, List, Tuple, Optional


warnings.filterwarnings('ignore')

print(f"enahopy versión: {enahopy.__version__}")
print(f"Inicio del análisis: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# enahopy versión: 0.6.0
# Inicio del análisis: 2025-10-29 19:30:19

# %%
# ========== CONFIGURACIÓN ENAHOModuleMerger ==========

# Configurar el merger para nivel individual (persona)
config = ModuleMergeConfig(merge_level=ModuleMergeLevel.PERSONA)
logger = logging.getLogger('enaho_merger')
merger = ENAHOModuleMerger(config, logger)


# Configurar el merger para nivel hogar
config_hogar = ModuleMergeConfig(merge_level=ModuleMergeLevel.HOGAR)
merger_hogar = ENAHOModuleMerger(config_hogar, logger)

# %%
def descargar_modulos_enaho(año: str = '2024') -> Dict:
    """
    Descarga múltiples módulos ENAHO usando enahopy.

    Args:
        año: Año de los datos ENAHO

4

        Dict con datasets por módulo
    """
    from enahopy.loader import ENAHODataDownloader

    print(f"\n{'=' * 70}")
    print(f"DESCARGANDO MÓDULOS ENAHO {año}".center(70))
    print(f"{'=' * 70}\n")

    modulos_interes = {
        "01": "Características de vivienda y hogar",
        "02": "Características de los Miembros del Hogar",
        "03": "Educación",
        "04": "Salud",
        "05": "Empleo e Ingresos",
        "34": "Sumarias (Variables Calculadas)"
    }

    downloader = ENAHODataDownloader(verbose=True)

    print("Módulos a descargar:")
    for code, desc in modulos_interes.items():
        print(f"  {code}: {desc}")

    data_multi = downloader.download(
        modules=list(modulos_interes.keys()),
        years=[año],
        output_dir=r"E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data",
        decompress=True,
        only_dta=True,
        load_dta=True,
        parallel=True,  # ¡Descarga paralela!
        max_workers=3,  # 3 módulos en paralelo
        verbose=True
    )
    print(f"\n✓ Descarga completada")
    return data_multi, modulos_interes


def extraer_datasets(data_multi: Dict, año: str = '2024') -> Dict:
    """
    Extrae datasets individuales del diccionario descargado.
    """
    print("Extrayendo datasets...")

    # Variables básicas para cada dataset
    vars_hogar = ['conglome', 'vivienda', 'hogar', 'p102', 'p103', 'p104', 'p105a', 'p110', 'p111a', 'p113a', 'p1121',
                  'p1144']
    vars_persona = ['conglome', 'vivienda', 'hogar', 'codperso', 'p203', 'p203b', 'p207', 'p208a', 'p209']
    vars_educa = ['conglome', 'vivienda', 'hogar', 'codperso', 'p301a', 'p301b', 'p301c', 'p307']
    vars_salud = ['conglome', 'vivienda', 'hogar', 'codperso', 'p401', 'p4191', 'p4192', 'p4193', 'p4194',
                  'p4195','p4196', 'p4197', 'p4198', 'p401h1', 'p401h2', 'p401h3', 'p401h4', 'p401h5', 'p401h6', 'p401f', 'p401g']
    vars_empleo = ['conglome', 'vivienda', 'hogar', 'codperso', 'ocu500', 'p507', 'i524e1', 'i524a1', 'p513t', 'p510a1',
                   'p512a', 'p558a5', 'i530a', 'p530a', 'i538e1', 'p538e1', 'i541a', 'p541a', 'p505r4', 'p506r4',
                   'p511a']
    vars_sumaria = ['conglome', 'vivienda', 'hogar', 'ubigeo', 'dominio', 'estrato', 'pobreza', 'inghog2d', 'gashog2d',
                    'factor07', 'mieperho', 'linea', 'linpe']

    # Cargar datasets
    data_caracteristica_hogar = data_multi[(año, '01')]['enaho01-' + año + '-100'][vars_hogar]
    data_caracteristica_persona = data_multi[(año, '02')]['enaho01-' + año + '-200'][vars_persona]
    data_educacion = data_multi[(año, '03')]['enaho01a-' + año + '-300'][vars_educa]
    data_salud = data_multi[(año, '04')]['enaho01a-' + año + '-400'][vars_salud]
    data_empleo = data_multi[(año, '05')]['enaho01a-' + año + '-500'][vars_empleo]
    data_sumaria = data_multi[(año, '34')]['sumaria-' + año][vars_sumaria]

    datasets = {
        'hogar': data_caracteristica_hogar,
        'persona': data_caracteristica_persona,
        'educacion': data_educacion,
        'salud': data_salud,
        'empleo': data_empleo,
        'sumaria': data_sumaria
    }

    # Mostrar resumen simple
    for nombre, df in datasets.items():
        print(f"  {nombre}: {df.shape[0]:,} filas × {df.shape[1]} columnas")

    return datasets

# %%
def fusionar_modulos_individuales(data_persona: pd.DataFrame,
                                  data_educacion: pd.DataFrame,
                                  data_salud: pd.DataFrame,
                                  data_empleo: pd.DataFrame) -> pd.DataFrame:
    """
    Fusiona todos los módulos individuales en un único DataFrame.
    Usa enahopy ENAHOModuleMerger para hacer merge correcto.
    """
    from enahopy.merger import ENAHOModuleMerger
    from enahopy.merger.config import ModuleMergeConfig, ModuleMergeLevel

    print(f"\n{'=' * 70}")
    print("PASO 1: FUSIÓN DE MÓDULOS INDIVIDUALES".center(70))
    print(f"{'=' * 70}\n")

    print("Fusionando datos individuales (persona + educación + salud + empleo)...\n")

    # Configurar merger para nivel PERSONA
    config = ModuleMergeConfig(merge_level=ModuleMergeLevel.PERSONA)
    logger_merger = logging.getLogger('enaho_merger')
    merger = ENAHOModuleMerger(config, logger_merger)

    modules_dict = {
        '02': data_persona,  # Características de miembros del hogar
        '04': data_salud,  # Salud
        '03': data_educacion,  # Educación
        '05': data_empleo  # Empleo
    }

    print("📦 Usando ENAHOModuleMerger de enahopy para fusionar módulos 02, 03, 04, 05...")
    merge_result = merger.merge_multiple_modules(
        modules_dict=modules_dict,
        base_module='02',  # Características como base
        merge_config=config
    )
    # Realizar merge usando enahopy
    data_individuos = merge_result.merged_df

    print(f"\n✓ Módulos individuales fusionados: {data_individuos.shape}")
    return data_individuos

# %%
def merge_con_hogar(data_caracteristica_hogar: pd.DataFrame,
                      data_sumaria: pd.DataFrame) -> pd.DataFrame:
    """
    Merge de datos agregados de nivel individual con sumaria (módulo 01).
    Usa enahopy para hacer merge correcto.
    """
    from enahopy.merger import ENAHOModuleMerger
    from enahopy.merger.config import ModuleMergeConfig, ModuleMergeLevel


    # Configurar merger para nivel HOGAR
    config_hogar = ModuleMergeConfig(merge_level=ModuleMergeLevel.HOGAR)
    logger_merger = logging.getLogger('enaho_merger')
    merger_hogar = ENAHOModuleMerger(config_hogar, logger_merger)



    print("\n📦 Usando ENAHOModuleMerger de enahopy para fusionar sumaria con caracteristicas del hogar...")
    merge_con_hogar = merger_hogar.merge_modules(
        left_df=data_sumaria,           # Sumaria como base (left)
        right_df=data_caracteristica_hogar,         # Datos agregados (right)
        left_module='34',           # Módulo sumaria
        right_module='01',    # Identificador para datos agregados
        merge_config=config_hogar
    )

    # Extraer el DataFrame resultante
    data_con_hogar = merge_con_hogar.merged_df

    print(f"\n✓ Módulos a nivel Hogares fusionados: {data_con_hogar.shape}")
    return data_con_hogar

# %%
# PASO 1: Descargar y extraer la información de INEI con ENAHOPY

data_multi, modulos = descargar_modulos_enaho('2024')
datasets = extraer_datasets(data_multi, '2024')

# PASO 2: Fusionar módulos individuales

data_individuos = fusionar_modulos_individuales(
    datasets['persona'],
    datasets['educacion'],
    datasets['salud'],
    datasets['empleo']
)

# PASO 3: Fusionar módulos de hogares 1 y sumaria

data_hogares = merge_con_hogar(
    datasets['hogar'],
    datasets['sumaria']
)
# Out:
# ======================================================================
#                     DESCARGANDO MÓDULOS ENAHO 2024
# ======================================================================
#
# 2025-10-29 19:30:37 | INFO     | enahopy | ENAHOPY logging initialized
# 2025-10-29 19:30:37 | DEBUG    | enahopy.loader.core.cache | No expired cache entries to clean
# Módulos a descargar:
#   01: Características de vivienda y hogar
#   02: Características de los Miembros del Hogar
#   03: Educación
#   04: Salud
#   05: Empleo e Ingresos
#   34: Sumarias (Variables Calculadas)
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | === Iniciando descarga ENAHO corte transversal ===
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Módulos: ['01', '02', '03', '04', '05', '34']
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Años: ['2024']
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Directorio: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Total de descargas programadas: 6
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Descarga paralela con 3 workers
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Descargando módulo 01 año 2024
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Descargando módulo 02 año 2024
# 2025-10-29 19:30:37 | INFO     | enaho_downloader | Descargando módulo 03 año 2024
# Descargando modulo_01_2024.zip:  30%|██▉       | 2.49M/8.38M [00:01<00:03, 1.77MiB/s]
# Descargando modulo_03_2024.zip:   0%|          | 0.00/11.9M [00:00<?, ?iB/s]
# Descargando modulo_01_2024.zip:  32%|███▏      | 2.69M/8.38M [00:01<00:03, 1.55MiB/s][A
# Descargando modulo_01_2024.zip:  34%|███▍      | 2.86M/8.38M [00:01<00:03, 1.42MiB/s][A
# Descargando modulo_01_2024.zip:  36%|███▋      | 3.05M/8.38M [00:02<00:03, 1.35MiB/s][A
# Descargando modulo_01_2024.zip:  38%|███▊      | 3.19M/8.38M [00:02<00:04, 1.22MiB/s]A
# Descargando modulo_01_2024.zip:  43%|████▎     | 3.59M/8.38M [00:02<00:04, 1.20MiB/s]A
# Descargando modulo_01_2024.zip:  45%|████▌     | 3.80M/8.38M [00:02<00:03, 1.39MiB/s]A
# Descargando modulo_01_2024.zip:  47%|████▋     | 3.96M/8.38M [00:02<00:03, 1.42MiB/s]A
# Descargando modulo_01_2024.zip:  50%|████▉     | 4.18M/8.38M [00:02<00:02, 1.61MiB/s]A
# Descargando modulo_01_2024.zip:  53%|█████▎    | 4.41M/8.38M [00:02<00:02, 1.74MiB/s]
# Descargando modulo_01_2024.zip:  58%|█████▊    | 4.85M/8.38M [00:03<00:02, 1.72MiB/s]
# Descargando modulo_01_2024.zip:  60%|██████    | 5.03M/8.38M [00:03<00:01, 1.73MiB/s]
# Descargando modulo_01_2024.zip:  62%|██████▏   | 5.21M/8.38M [00:03<00:01, 1.74MiB/s]
# Descargando modulo_01_2024.zip:  65%|██████▍   | 5.42M/8.38M [00:03<00:01, 1.82MiB/s]
# Descargando modulo_01_2024.zip:  67%|██████▋   | 5.61M/8.38M [00:03<00:01, 1.70MiB/s]
# Descargando modulo_01_2024.zip:  69%|██████▉   | 5.79M/8.38M [00:03<00:01, 1.59MiB/s]
# Descargando modulo_01_2024.zip:  72%|███████▏  | 6.00M/8.38M [00:03<00:01, 1.70MiB/s]
# Descargando modulo_01_2024.zip:  74%|███████▎  | 6.18M/8.38M [00:04<00:01, 1.65MiB/s]
# Descargando modulo_01_2024.zip:  76%|███████▌  | 6.36M/8.38M [00:04<00:01, 1.69MiB/s]
# Descargando modulo_01_2024.zip:  78%|███████▊  | 6.53M/8.38M [00:04<00:01, 1.44MiB/s]
# Descargando modulo_01_2024.zip:  80%|███████▉  | 6.68M/8.38M [00:04<00:01, 1.36MiB/s]
# Descargando modulo_01_2024.zip:  82%|████████▏ | 6.83M/8.38M [00:04<00:01, 1.34MiB/s]
# Descargando modulo_01_2024.zip:  84%|████████▍ | 7.05M/8.38M [00:04<00:00, 1.50MiB/s]
# Descargando modulo_01_2024.zip:  86%|████████▌ | 7.21M/8.38M [00:04<00:00, 1.53MiB/s]
# Descargando modulo_01_2024.zip:  88%|████████▊ | 7.37M/8.38M [00:04<00:00, 1.53MiB/s]
#
# Descargando modulo_02_2024.zip:   0%|          | 0.00/5.79M [00:00<?, ?iB/s]
# Descargando modulo_01_2024.zip:  90%|████████▉ | 7.54M/8.38M [00:05<00:00, 1.47MiB/s]
#
# Descargando modulo_02_2024.zip:   3%|▎         | 164k/5.79M [00:00<00:03, 1.63MiB/s]
# Descargando modulo_01_2024.zip:  92%|█████████▏| 7.69M/8.38M [00:05<00:00, 1.48MiB/s]
#
# Descargando modulo_02_2024.zip:   6%|▌         | 328k/5.79M [00:00<00:03, 1.57MiB/s]
# Descargando modulo_01_2024.zip:  94%|█████████▎| 7.85M/8.38M [00:05<00:00, 1.45MiB/s]
#
# Descargando modulo_02_2024.zip:   8%|▊         | 492k/5.79M [00:00<00:03, 1.51MiB/s]
# Descargando modulo_01_2024.zip:  95%|█████████▌| 8.00M/8.38M [00:05<00:00, 1.37MiB/s]
#
# Descargando modulo_02_2024.zip:  11%|█         | 647k/5.79M [00:00<00:03, 1.43MiB/s]
# Descargando modulo_01_2024.zip:  97%|█████████▋| 8.13M/8.38M [00:05<00:00, 1.36MiB/s]
#
# Descargando modulo_02_2024.zip:  14%|█▎        | 795k/5.79M [00:00<00:03, 1.28MiB/s]
# Descargando modulo_01_2024.zip:  99%|█████████▊| 8.27M/8.38M [00:05<00:00, 1.32MiB/s]
#
# Descargando modulo_02_2024.zip:  16%|█▌        | 926k/5.79M [00:00<00:03, 1.28MiB/s]
# Descargando modulo_01_2024.zip: 100%|██████████| 8.38M/8.38M [00:05<00:00, 1.49MiB/s]
#
#
# Descargando modulo_02_2024.zip:  19%|█▊        | 1.08M/5.79M [00:00<00:03, 1.33MiB/s]
# Descargando modulo_03_2024.zip:  38%|███▊      | 4.55M/11.9M [00:04<00:06, 1.19MiB/s]
# 2025-10-29 19:31:05 | INFO     | enaho_downloader | Descarga completada: modulo_01_2024.zip (8.0 MB)
# Descargando modulo_02_2024.zip:  21%|██        | 1.22M/5.79M [00:00<00:04, 1.12MiB/s]
# Descargando modulo_03_2024.zip:  40%|███▉      | 4.70M/11.9M [00:04<00:05, 1.25MiB/s]
# 2025-10-29 19:31:05 | INFO     | enaho_downloader | Extraídos 1 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_01_2024
# 2025-10-29 19:31:05 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_01_2024.zip
# Descargando modulo_02_2024.zip:  23%|██▎       | 1.34M/5.79M [00:01<00:03, 1.14MiB/s]
# Descargando modulo_03_2024.zip:  41%|████      | 4.87M/11.9M [00:04<00:05, 1.32MiB/s]
#
# Descargando modulo_02_2024.zip:  26%|██▌       | 1.49M/5.79M [00:01<00:03, 1.20MiB/s]
# Descargando modulo_03_2024.zip:  42%|████▏     | 5.01M/11.9M [00:04<00:05, 1.30MiB/s]
#
# Descargando modulo_02_2024.zip:  29%|██▊       | 1.65M/5.79M [00:01<00:03, 1.30MiB/s]
# Descargando modulo_03_2024.zip:  43%|████▎     | 5.16M/11.9M [00:04<00:05, 1.33MiB/s]
#
# Descargando modulo_02_2024.zip:  31%|███       | 1.79M/5.79M [00:03<00:24, 166kiB/s]
# Descargando modulo_03_2024.zip:  45%|████▍     | 5.30M/11.9M [00:07<00:38, 169kiB/s]
#
# Descargando modulo_02_2024.zip:  35%|███▍      | 2.02M/5.79M [00:04<00:14, 260kiB/s]
# Descargando modulo_03_2024.zip:  46%|████▋     | 5.52M/11.9M [00:07<00:24, 263kiB/s]
#
# Descargando modulo_02_2024.zip:  37%|███▋      | 2.14M/5.79M [00:04<00:13, 271kiB/s]
# Descargando modulo_03_2024.zip:  48%|████▊     | 5.65M/11.9M [00:07<00:24, 256kiB/s]
#
# Descargando modulo_02_2024.zip:  39%|███▊      | 2.24M/5.79M [00:04<00:12, 295kiB/s]
# Descargando modulo_03_2024.zip:  50%|████▉     | 5.90M/11.9M [00:07<00:15, 394kiB/s]
#
# Descargando modulo_02_2024.zip:  42%|████▏     | 2.44M/5.79M [00:04<00:07, 437kiB/s]
# Descargando modulo_03_2024.zip:  51%|█████     | 6.04M/11.9M [00:08<00:12, 470kiB/s]
#
# Descargando modulo_02_2024.zip:  44%|████▍     | 2.56M/5.79M [00:04<00:06, 487kiB/s]
# Descargando modulo_03_2024.zip:  52%|█████▏    | 6.17M/11.9M [00:08<00:10, 540kiB/s]
#
# Descargando modulo_02_2024.zip:  46%|████▌     | 2.66M/5.79M [00:05<00:05, 557kiB/s]
# Descargando modulo_03_2024.zip:  53%|█████▎    | 6.29M/11.9M [00:08<00:09, 578kiB/s]
#
# Descargando modulo_02_2024.zip:  48%|████▊     | 2.77M/5.79M [00:05<00:05, 532kiB/s]
# Descargando modulo_03_2024.zip:  54%|█████▍    | 6.40M/11.9M [00:08<00:09, 602kiB/s]
#
# Descargando modulo_02_2024.zip:  49%|████▉     | 2.86M/5.79M [00:05<00:05, 570kiB/s]
# Descargando modulo_03_2024.zip:  55%|█████▍    | 6.50M/11.9M [00:08<00:08, 645kiB/s]
#
# Descargando modulo_02_2024.zip:  51%|█████     | 2.94M/5.79M [00:05<00:04, 614kiB/s]
# Descargando modulo_03_2024.zip:  56%|█████▌    | 6.60M/11.9M [00:08<00:07, 715kiB/s]
#
# Descargando modulo_02_2024.zip:  52%|█████▏    | 3.02M/5.79M [00:05<00:05, 539kiB/s]
#
# Descargando modulo_02_2024.zip:  53%|█████▎    | 3.10M/5.79M [00:05<00:04, 541kiB/s]
#
# Descargando modulo_02_2024.zip:  56%|█████▌    | 3.24M/5.79M [00:05<00:03, 717kiB/s]
# Descargando modulo_03_2024.zip:  56%|█████▋    | 6.70M/11.9M [00:09<00:13, 371kiB/s]
#
# Descargando modulo_02_2024.zip:  58%|█████▊    | 3.33M/5.79M [00:06<00:04, 511kiB/s]
#
# Descargando modulo_02_2024.zip:  59%|█████▉    | 3.41M/5.79M [00:06<00:05, 413kiB/s]
#
# Descargando modulo_02_2024.zip:  61%|██████    | 3.53M/5.79M [00:06<00:04, 541kiB/s]
#
# Descargando modulo_02_2024.zip:  62%|██████▏   | 3.61M/5.79M [00:06<00:04, 545kiB/s]
#
# Descargando modulo_02_2024.zip:  64%|██████▎   | 3.69M/5.79M [00:06<00:04, 490kiB/s]
#
# Descargando modulo_02_2024.zip:  65%|██████▍   | 3.75M/5.79M [00:07<00:03, 518kiB/s]
#
# Descargando modulo_02_2024.zip:  66%|██████▋   | 3.84M/5.79M [00:07<00:03, 597kiB/s]
#
# Descargando modulo_02_2024.zip:  68%|██████▊   | 3.92M/5.79M [00:07<00:03, 622kiB/s]
#
# Descargando modulo_02_2024.zip:  72%|███████▏  | 4.16M/5.79M [00:07<00:01, 1.07MiB/s]
#
# Descargando modulo_02_2024.zip:  74%|███████▍  | 4.29M/5.79M [00:07<00:01, 1.05MiB/s]
#
# Descargando modulo_02_2024.zip:  78%|███████▊  | 4.54M/5.79M [00:07<00:00, 1.37MiB/s]
#
# Descargando modulo_02_2024.zip:  81%|████████  | 4.69M/5.79M [00:07<00:00, 1.27MiB/s]
#
# Descargando modulo_02_2024.zip:  83%|████████▎ | 4.83M/5.79M [00:07<00:00, 1.09MiB/s]
# 2025-10-29 19:31:12 | INFO     | enaho_downloader | Archivo cargado: enaho01-2024-100.dta (44731 filas)
# 2025-10-29 19:31:12 | INFO     | enaho_downloader | Descargando módulo 04 año 2024
# Descargando modulo_02_2024.zip:  87%|████████▋ | 5.06M/5.79M [00:08<00:00, 1.39MiB/s]
#
# Descargando modulo_02_2024.zip:  91%|█████████ | 5.24M/5.79M [00:08<00:00, 1.25MiB/s]
#
# Descargando modulo_02_2024.zip:  95%|█████████▍| 5.49M/5.79M [00:08<00:00, 1.52MiB/s]
#
# Descargando modulo_02_2024.zip: 100%|██████████| 5.79M/5.79M [00:08<00:00, 683kiB/s]
# 2025-10-29 19:31:13 | INFO     | enaho_downloader | Descarga completada: modulo_02_2024.zip (5.5 MB)
# 2025-10-29 19:31:13 | INFO     | enaho_downloader | Extraídos 3 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_02_2024
# 2025-10-29 19:31:13 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_02_2024.zip
# Descargando modulo_04_2024.zip:   0%|          | 0.00/14.2M [00:00<?, ?iB/s]
# Descargando modulo_04_2024.zip:   2%|▏         | 213k/14.2M [00:00<00:18, 774kiB/s] ]
# Descargando modulo_04_2024.zip:   2%|▏         | 295k/14.2M [00:00<00:19, 709kiB/s]s]
# Descargando modulo_04_2024.zip:   3%|▎         | 426k/14.2M [00:00<00:31, 434kiB/s]s]
# Descargando modulo_04_2024.zip:   4%|▎         | 524k/14.2M [00:01<00:25, 536kiB/s]s]
# Descargando modulo_03_2024.zip:  58%|█████▊    | 6.95M/11.9M [00:14<00:47, 105kiB/s]
# Descargando modulo_04_2024.zip:   4%|▍         | 590k/14.2M [00:01<00:31, 430kiB/s]]
# 2025-10-29 19:31:16 | INFO     | enaho_downloader | Archivo cargado: enaho01-2024-200.dta (117721 filas)
# 2025-10-29 19:31:16 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_ciuo_88.dta (5195 filas)
# 2025-10-29 19:31:16 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_cno_2015.dta (473 filas)
# Descargando modulo_04_2024.zip:   6%|▌         | 819k/14.2M [00:01<00:16, 786kiB/s]
# 2025-10-29 19:31:16 | INFO     | enaho_downloader | Descargando módulo 05 año 2024
# Descargando modulo_03_2024.zip:  60%|██████    | 7.14M/11.9M [00:14<00:18, 254kiB/s]
# Descargando modulo_04_2024.zip:   7%|▋         | 967k/14.2M [00:01<00:23, 556kiB/s]]
# Descargando modulo_04_2024.zip:   8%|▊         | 1.16M/14.2M [00:01<00:16, 778kiB/s]
# Descargando modulo_04_2024.zip:  10%|▉         | 1.36M/14.2M [00:01<00:13, 980kiB/s]
# Descargando modulo_03_2024.zip:  64%|██████▍   | 7.62M/11.9M [00:15<00:06, 621kiB/s]
#
# Descargando modulo_04_2024.zip:  11%|█         | 1.54M/14.2M [00:02<00:11, 1.12MiB/s]
# Descargando modulo_03_2024.zip:  65%|██████▌   | 7.77M/11.9M [00:15<00:05, 747kiB/s]
#
# Descargando modulo_04_2024.zip:  12%|█▏        | 1.69M/14.2M [00:02<00:12, 1.03MiB/s][A
# Descargando modulo_03_2024.zip:  66%|██████▋   | 7.87M/11.9M [00:15<00:05, 789kiB/s]
#
# Descargando modulo_05_2024.zip:   1%|▏         | 229k/16.7M [00:00<00:16, 985kiB/s]
# Descargando modulo_04_2024.zip:  13%|█▎        | 1.82M/14.2M [00:02<00:12, 976kiB/s] [A
#
# Descargando modulo_05_2024.zip:   2%|▏         | 336k/16.7M [00:00<00:16, 981kiB/s]
# Descargando modulo_03_2024.zip:  68%|██████▊   | 8.13M/11.9M [00:15<00:03, 976kiB/s]
#
# Descargando modulo_04_2024.zip:  14%|█▎        | 1.93M/14.2M [00:02<00:12, 989kiB/s]
# Descargando modulo_03_2024.zip:  70%|██████▉   | 8.29M/11.9M [00:16<00:03, 1.14MiB/s]
#
# Descargando modulo_04_2024.zip:  15%|█▍        | 2.06M/14.2M [00:02<00:11, 1.03MiB/s][A
# Descargando modulo_04_2024.zip:  15%|█▌        | 2.18M/14.2M [00:02<00:11, 1.04MiB/s]
#
# Descargando modulo_05_2024.zip:   5%|▍         | 786k/16.7M [00:00<00:12, 1.26MiB/s]
# Descargando modulo_03_2024.zip:  72%|███████▏  | 8.55M/11.9M [00:16<00:02, 1.15MiB/s]
#
# Descargando modulo_04_2024.zip:  17%|█▋        | 2.44M/14.2M [00:02<00:10, 1.15MiB/s][A
# Descargando modulo_03_2024.zip:  74%|███████▎  | 8.73M/11.9M [00:16<00:03, 986kiB/s]
#
# Descargando modulo_04_2024.zip:  18%|█▊        | 2.56M/14.2M [00:03<00:10, 1.14MiB/s]
# Descargando modulo_03_2024.zip:  75%|███████▍  | 8.90M/11.9M [00:16<00:02, 1.12MiB/s]
#
# Descargando modulo_04_2024.zip:  19%|█▉        | 2.69M/14.2M [00:03<00:10, 1.15MiB/s]
# Descargando modulo_03_2024.zip:  76%|███████▋  | 9.06M/11.9M [00:16<00:02, 1.23MiB/s]
#
# Descargando modulo_04_2024.zip:  20%|██        | 2.85M/14.2M [00:03<00:10, 1.12MiB/s]
# Descargando modulo_03_2024.zip:  77%|███████▋  | 9.20M/11.9M [00:16<00:02, 1.24MiB/s]
#
# Descargando modulo_04_2024.zip:  21%|██▏       | 3.03M/14.2M [00:03<00:08, 1.28MiB/s]
# Descargando modulo_03_2024.zip:  79%|███████▉  | 9.36M/11.9M [00:16<00:01, 1.27MiB/s]
#
# Descargando modulo_04_2024.zip:  23%|██▎       | 3.19M/14.2M [00:03<00:08, 1.32MiB/s]
# Descargando modulo_03_2024.zip:  80%|████████  | 9.54M/11.9M [00:17<00:01, 1.36MiB/s]
#
# Descargando modulo_04_2024.zip:  24%|██▎       | 3.36M/14.2M [00:03<00:07, 1.36MiB/s]
# Descargando modulo_03_2024.zip:  82%|████████▏ | 9.72M/11.9M [00:17<00:01, 1.47MiB/s]
#
# Descargando modulo_04_2024.zip:  25%|██▍       | 3.52M/14.2M [00:03<00:07, 1.42MiB/s]
# Descargando modulo_03_2024.zip:  83%|████████▎ | 9.87M/11.9M [00:17<00:01, 1.47MiB/s]
#
# Descargando modulo_04_2024.zip:  26%|██▌       | 3.67M/14.2M [00:03<00:08, 1.28MiB/s]
# Descargando modulo_03_2024.zip:  84%|████████▍ | 10.0M/11.9M [00:17<00:01, 1.30MiB/s]
#
# Descargando modulo_04_2024.zip:  27%|██▋       | 3.82M/14.2M [00:03<00:08, 1.28MiB/s]
# Descargando modulo_03_2024.zip:  86%|████████▌ | 10.2M/11.9M [00:17<00:01, 1.28MiB/s]
#
# Descargando modulo_04_2024.zip:  28%|██▊       | 3.95M/14.2M [00:04<00:08, 1.23MiB/s]
#
# Descargando modulo_05_2024.zip:  16%|█▌        | 2.60M/16.7M [00:02<00:11, 1.24MiB/s]
# Descargando modulo_04_2024.zip:  29%|██▉       | 4.11M/14.2M [00:04<00:07, 1.30MiB/s]
#
# Descargando modulo_04_2024.zip:  30%|███       | 4.25M/14.2M [00:04<00:07, 1.24MiB/s]
# Descargando modulo_03_2024.zip:  88%|████████▊ | 10.5M/11.9M [00:17<00:01, 1.10MiB/s]
#
# Descargando modulo_04_2024.zip:  31%|███       | 4.38M/14.2M [00:04<00:08, 1.15MiB/s]
# Descargando modulo_03_2024.zip:  89%|████████▉ | 10.6M/11.9M [00:17<00:01, 1.03MiB/s]
#
# Descargando modulo_04_2024.zip:  32%|███▏      | 4.51M/14.2M [00:04<00:08, 1.15MiB/s]
# Descargando modulo_03_2024.zip:  90%|█████████ | 10.7M/11.9M [00:18<00:01, 1.08MiB/s]
#
# Descargando modulo_05_2024.zip:  19%|█▊        | 3.12M/16.7M [00:02<00:11, 1.19MiB/s]
# Descargando modulo_04_2024.zip:  33%|███▎      | 4.64M/14.2M [00:04<00:08, 1.16MiB/s]
#
# Descargando modulo_05_2024.zip:  19%|█▉        | 3.26M/16.7M [00:02<00:11, 1.16MiB/s]
# Descargando modulo_04_2024.zip:  34%|███▎      | 4.76M/14.2M [00:04<00:08, 1.15MiB/s]
#
# Descargando modulo_05_2024.zip:  20%|██        | 3.39M/16.7M [00:02<00:11, 1.15MiB/s]
# Descargando modulo_04_2024.zip:  34%|███▍      | 4.88M/14.2M [00:04<00:08, 1.15MiB/s]
# Descargando modulo_03_2024.zip:  94%|█████████▍| 11.2M/11.9M [00:18<00:00, 1.21MiB/s]
#
# Descargando modulo_04_2024.zip:  36%|███▌      | 5.05M/14.2M [00:05<00:07, 1.23MiB/s]
#
# Descargando modulo_05_2024.zip:  22%|██▏       | 3.72M/16.7M [00:03<00:09, 1.35MiB/s]
# Descargando modulo_04_2024.zip:  37%|███▋      | 5.21M/14.2M [00:05<00:06, 1.29MiB/s]
#
# Descargando modulo_05_2024.zip:  23%|██▎       | 3.86M/16.7M [00:03<00:09, 1.29MiB/s]
# Descargando modulo_04_2024.zip:  38%|███▊      | 5.34M/14.2M [00:05<00:06, 1.27MiB/s]
#
# Descargando modulo_05_2024.zip:  24%|██▍       | 4.01M/16.7M [00:03<00:09, 1.36MiB/s]
# Descargando modulo_04_2024.zip:  39%|███▉      | 5.51M/14.2M [00:05<00:06, 1.33MiB/s]
#
# Descargando modulo_05_2024.zip:  25%|██▍       | 4.18M/16.7M [00:03<00:08, 1.41MiB/s]
# Descargando modulo_03_2024.zip: 100%|██████████| 11.9M/11.9M [00:18<00:00, 626kiB/s]
#
#
# Descargando modulo_04_2024.zip:  41%|████▏     | 5.85M/14.2M [00:05<00:05, 1.48MiB/s]
#
# Descargando modulo_04_2024.zip:  43%|████▎     | 6.05M/14.2M [00:05<00:05, 1.46MiB/s]
#
# Descargando modulo_05_2024.zip:  28%|██▊       | 4.73M/16.7M [00:03<00:07, 1.50MiB/s]
# 2025-10-29 19:31:20 | INFO     | enaho_downloader | Descarga completada: modulo_03_2024.zip (11.3 MB)
# Descargando modulo_04_2024.zip:  44%|████▍     | 6.24M/14.2M [00:05<00:05, 1.44MiB/s]
#
# Descargando modulo_04_2024.zip:  45%|████▌     | 6.39M/14.2M [00:05<00:05, 1.40MiB/s]
#
# Descargando modulo_04_2024.zip:  46%|████▋     | 6.57M/14.2M [00:06<00:05, 1.36MiB/s]
#
# Descargando modulo_05_2024.zip:  31%|███▏      | 5.23M/16.7M [00:04<00:07, 1.47MiB/s]
# 2025-10-29 19:31:20 | INFO     | enaho_downloader | Extraídos 1 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_03_2024
# 2025-10-29 19:31:20 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_03_2024.zip
# Descargando modulo_04_2024.zip:  48%|████▊     | 6.77M/14.2M [00:06<00:04, 1.52MiB/s]
#
# Descargando modulo_04_2024.zip:  49%|████▉     | 6.96M/14.2M [00:06<00:04, 1.61MiB/s]
#
# Descargando modulo_04_2024.zip:  51%|█████     | 7.15M/14.2M [00:06<00:04, 1.68MiB/s]
#
# Descargando modulo_04_2024.zip:  52%|█████▏    | 7.36M/14.2M [00:06<00:04, 1.68MiB/s]
#
# Descargando modulo_05_2024.zip:  36%|███▌      | 5.96M/16.7M [00:04<00:07, 1.46MiB/s]
#
# Descargando modulo_04_2024.zip:  53%|█████▎    | 7.53M/14.2M [00:06<00:05, 1.21MiB/s]
#
# Descargando modulo_05_2024.zip:  38%|███▊      | 6.28M/16.7M [00:04<00:07, 1.36MiB/s]
#
# Descargando modulo_05_2024.zip:  39%|███▊      | 6.47M/16.7M [00:04<00:06, 1.50MiB/s]
#
# Descargando modulo_04_2024.zip:  54%|█████▍    | 7.68M/14.2M [00:13<01:10, 92.4kiB/s]
#
# Descargando modulo_04_2024.zip:  56%|█████▋    | 7.99M/14.2M [00:14<00:53, 115kiB/s]
#
# Descargando modulo_04_2024.zip:  57%|█████▋    | 8.13M/14.2M [00:15<00:40, 150kiB/s]
#
# Descargando modulo_04_2024.zip:  59%|█████▉    | 8.40M/14.2M [00:15<00:21, 271kiB/s]
#
# Descargando modulo_04_2024.zip:  60%|█████▉    | 8.49M/14.2M [00:15<00:17, 321kiB/s]
#
# Descargando modulo_04_2024.zip:  61%|██████    | 8.59M/14.2M [00:15<00:14, 387kiB/s]
#
# Descargando modulo_04_2024.zip:  61%|██████▏   | 8.70M/14.2M [00:15<00:11, 472kiB/s]
#
# Descargando modulo_05_2024.zip:  44%|████▍     | 7.36M/16.7M [00:13<00:35, 267kiB/s]
#
# Descargando modulo_05_2024.zip:  44%|████▍     | 7.44M/16.7M [00:13<00:30, 301kiB/s]
#
# Descargando modulo_04_2024.zip:  62%|██████▏   | 8.79M/14.2M [00:16<00:13, 389kiB/s]
#
# Descargando modulo_04_2024.zip:  63%|██████▎   | 8.90M/14.2M [00:16<00:10, 486kiB/s]
#
# Descargando modulo_04_2024.zip:  63%|██████▎   | 8.99M/14.2M [00:16<00:10, 475kiB/s]
#
# Descargando modulo_04_2024.zip:  64%|██████▍   | 9.06M/14.2M [00:16<00:10, 488kiB/s]
#
# Descargando modulo_04_2024.zip:  64%|██████▍   | 9.13M/14.2M [00:16<00:10, 494kiB/s]
#
# Descargando modulo_04_2024.zip:  65%|██████▌   | 9.23M/14.2M [00:16<00:08, 600kiB/s]
#
# Descargando modulo_04_2024.zip:  66%|██████▌   | 9.32M/14.2M [00:16<00:07, 633kiB/s]
#
# Descargando modulo_04_2024.zip:  66%|██████▋   | 9.40M/14.2M [00:17<00:08, 582kiB/s]
#
# Descargando modulo_04_2024.zip:  67%|██████▋   | 9.49M/14.2M [00:17<00:07, 645kiB/s]
#
# Descargando modulo_04_2024.zip:  68%|██████▊   | 9.57M/14.2M [00:17<00:06, 665kiB/s]
#
# Descargando modulo_04_2024.zip:  68%|██████▊   | 9.64M/14.2M [00:17<00:06, 678kiB/s]
#
# Descargando modulo_04_2024.zip:  69%|██████▊   | 9.72M/14.2M [00:17<00:07, 598kiB/s]
#
# Descargando modulo_04_2024.zip:  69%|██████▉   | 9.78M/14.2M [00:17<00:07, 589kiB/s]
#
# Descargando modulo_04_2024.zip:  70%|██████▉   | 9.85M/14.2M [00:17<00:07, 585kiB/s]
#
# Descargando modulo_04_2024.zip:  70%|███████   | 9.97M/14.2M [00:17<00:05, 751kiB/s]
#
# Descargando modulo_04_2024.zip:  71%|███████   | 10.1M/14.2M [00:17<00:05, 759kiB/s]
#
# Descargando modulo_05_2024.zip:  50%|█████     | 8.40M/16.7M [00:15<00:16, 519kiB/s]
#
# Descargando modulo_04_2024.zip:  72%|███████▏  | 10.1M/14.2M [00:18<00:07, 553kiB/s]
#
# Descargando modulo_05_2024.zip:  51%|█████     | 8.54M/16.7M [00:16<00:15, 513kiB/s]
#
# Descargando modulo_05_2024.zip:  52%|█████▏    | 8.62M/16.7M [00:16<00:15, 517kiB/s]
#
# Descargando modulo_04_2024.zip:  72%|███████▏  | 10.2M/14.2M [00:18<00:11, 339kiB/s]
#
# Descargando modulo_05_2024.zip:  52%|█████▏    | 8.76M/16.7M [00:16<00:13, 585kiB/s]
#
# Descargando modulo_04_2024.zip:  72%|███████▏  | 10.3M/14.2M [00:18<00:12, 301kiB/s]
#
# Descargando modulo_04_2024.zip:  73%|███████▎  | 10.3M/14.2M [00:19<00:10, 371kiB/s]
#
# Descargando modulo_04_2024.zip:  73%|███████▎  | 10.4M/14.2M [00:19<00:10, 366kiB/s]
#
# Descargando modulo_05_2024.zip:  54%|█████▍    | 8.99M/16.7M [00:17<00:15, 484kiB/s]
#
# Descargando modulo_05_2024.zip:  54%|█████▍    | 9.05M/16.7M [00:17<00:15, 492kiB/s]
#
# Descargando modulo_04_2024.zip:  74%|███████▍  | 10.5M/14.2M [00:19<00:10, 346kiB/s]
#
# Descargando modulo_05_2024.zip:  55%|█████▍    | 9.19M/16.7M [00:17<00:13, 570kiB/s]
#
# Descargando modulo_04_2024.zip:  75%|███████▍  | 10.6M/14.2M [00:19<00:09, 359kiB/s]
#
# Descargando modulo_04_2024.zip:  75%|███████▌  | 10.7M/14.2M [00:19<00:09, 362kiB/s]
#
# Descargando modulo_04_2024.zip:  76%|███████▌  | 10.7M/14.2M [00:20<00:08, 415kiB/s]
#
# Descargando modulo_04_2024.zip:  76%|███████▌  | 10.8M/14.2M [00:20<00:07, 442kiB/s]
#
# Descargando modulo_04_2024.zip:  77%|███████▋  | 10.8M/14.2M [00:20<00:09, 362kiB/s]
#
# Descargando modulo_04_2024.zip:  77%|███████▋  | 10.9M/14.2M [00:20<00:08, 398kiB/s]
#
# Descargando modulo_04_2024.zip:  77%|███████▋  | 10.9M/14.2M [00:20<00:07, 418kiB/s]
#
# Descargando modulo_04_2024.zip:  78%|███████▊  | 11.0M/14.2M [00:20<00:08, 382kiB/s]
#
# Descargando modulo_04_2024.zip:  78%|███████▊  | 11.0M/14.2M [00:20<00:09, 331kiB/s]
#
# Descargando modulo_04_2024.zip:  78%|███████▊  | 11.1M/14.2M [00:21<00:07, 397kiB/s]
#
# Descargando modulo_04_2024.zip:  79%|███████▉  | 11.2M/14.2M [00:21<00:08, 373kiB/s]
#
# Descargando modulo_04_2024.zip:  79%|███████▉  | 11.2M/14.2M [00:21<00:07, 377kiB/s]
#
# Descargando modulo_04_2024.zip:  79%|███████▉  | 11.2M/14.2M [00:21<00:07, 372kiB/s]
#
# Descargando modulo_04_2024.zip:  80%|███████▉  | 11.3M/14.2M [00:21<00:08, 342kiB/s]
#
# Descargando modulo_04_2024.zip:  80%|████████  | 11.3M/14.2M [00:21<00:08, 350kiB/s]
#
# Descargando modulo_04_2024.zip:  80%|████████  | 11.4M/14.2M [00:21<00:07, 361kiB/s]
#
# Descargando modulo_04_2024.zip:  81%|████████  | 11.4M/14.2M [00:21<00:07, 347kiB/s]
#
# Descargando modulo_04_2024.zip:  81%|████████  | 11.5M/14.2M [00:22<00:09, 297kiB/s]
#
# Descargando modulo_04_2024.zip:  82%|████████▏ | 11.6M/14.2M [00:22<00:05, 452kiB/s]
#
# Descargando modulo_04_2024.zip:  82%|████████▏ | 11.6M/14.2M [00:22<00:04, 522kiB/s]
#
# Descargando modulo_04_2024.zip:  83%|████████▎ | 11.7M/14.2M [00:22<00:05, 492kiB/s]
#
# Descargando modulo_04_2024.zip:  83%|████████▎ | 11.7M/14.2M [00:22<00:04, 484kiB/s]
#
# Descargando modulo_04_2024.zip:  83%|████████▎ | 11.8M/14.2M [00:22<00:05, 401kiB/s]
#
# Descargando modulo_04_2024.zip:  84%|████████▍ | 11.9M/14.2M [00:22<00:05, 437kiB/s]
#
# Descargando modulo_04_2024.zip:  84%|████████▍ | 11.9M/14.2M [00:23<00:05, 433kiB/s]
#
# Descargando modulo_04_2024.zip:  85%|████████▍ | 12.0M/14.2M [00:23<00:05, 395kiB/s]
#
# Descargando modulo_04_2024.zip:  85%|████████▍ | 12.0M/14.2M [00:23<00:05, 411kiB/s]
#
# Descargando modulo_04_2024.zip:  85%|████████▌ | 12.1M/14.2M [00:23<00:05, 408kiB/s]
#
# Descargando modulo_04_2024.zip:  86%|████████▌ | 12.1M/14.2M [00:23<00:05, 406kiB/s]
#
# Descargando modulo_04_2024.zip:  86%|████████▌ | 12.2M/14.2M [00:23<00:05, 366kiB/s]
#
# Descargando modulo_04_2024.zip:  86%|████████▌ | 12.2M/14.2M [00:23<00:05, 367kiB/s]
#
# Descargando modulo_04_2024.zip:  86%|████████▋ | 12.2M/14.2M [00:23<00:06, 296kiB/s]
#
# Descargando modulo_04_2024.zip:  87%|████████▋ | 12.3M/14.2M [00:24<00:06, 295kiB/s]
#
# Descargando modulo_04_2024.zip:  87%|████████▋ | 12.3M/14.2M [00:24<00:06, 274kiB/s]
#
# Descargando modulo_04_2024.zip:  87%|████████▋ | 12.4M/14.2M [00:24<00:04, 361kiB/s]
#
# Descargando modulo_04_2024.zip:  88%|████████▊ | 12.4M/14.2M [00:24<00:04, 361kiB/s]
#
# Descargando modulo_04_2024.zip:  89%|████████▊ | 12.5M/14.2M [00:24<00:02, 580kiB/s]
#
# Descargando modulo_04_2024.zip:  89%|████████▉ | 12.6M/14.2M [00:24<00:02, 597kiB/s]
#
# Descargando modulo_04_2024.zip:  90%|████████▉ | 12.7M/14.2M [00:24<00:01, 738kiB/s]
#
# Descargando modulo_04_2024.zip:  91%|█████████ | 12.9M/14.2M [00:25<00:02, 611kiB/s]
# 2025-10-29 19:31:39 | INFO     | enaho_downloader | Archivo cargado: enaho01a-2024-300.dta (106619 filas)
# 2025-10-29 19:31:39 | INFO     | enaho_downloader | Descargando módulo 34 año 2024
# Descargando modulo_04_2024.zip:  92%|█████████▏| 13.0M/14.2M [00:25<00:02, 488kiB/s]
#
# Descargando modulo_04_2024.zip:  93%|█████████▎| 13.2M/14.2M [00:25<00:01, 601kiB/s]
#
# Descargando modulo_04_2024.zip:  94%|█████████▎| 13.3M/14.2M [00:25<00:01, 647kiB/s]
#
# Descargando modulo_04_2024.zip:  95%|█████████▍| 13.4M/14.2M [00:25<00:00, 767kiB/s]
#
# Descargando modulo_05_2024.zip:  74%|███████▍  | 12.3M/16.7M [00:23<00:04, 1.05MiB/s]
#
# Descargando modulo_04_2024.zip:  95%|█████████▌| 13.5M/14.2M [00:25<00:00, 801kiB/s]]
#
# Descargando modulo_04_2024.zip:  96%|█████████▌| 13.6M/14.2M [00:26<00:00, 648kiB/s]
# Descargando modulo_34_2024.zip:   0%|          | 0.00/15.9M [00:00<?, ?iB/s]
#
# Descargando modulo_04_2024.zip:  97%|█████████▋| 13.7M/14.2M [00:26<00:00, 697kiB/s]]
#
# Descargando modulo_05_2024.zip:  77%|███████▋  | 12.9M/16.7M [00:24<00:03, 1.15MiB/s]
# Descargando modulo_04_2024.zip:  98%|█████████▊| 13.8M/14.2M [00:26<00:00, 574kiB/s]
#
# Descargando modulo_04_2024.zip: 100%|██████████| 14.2M/14.2M [00:26<00:00, 528kiB/s]
#
# Descargando modulo_34_2024.zip:   0%|          | 65.5k/15.9M [00:00<02:29, 106kiB/s]
#
# Descargando modulo_05_2024.zip:  79%|███████▉  | 13.2M/16.7M [00:24<00:04, 776kiB/s]
# Descargando modulo_34_2024.zip:   1%|          | 131k/15.9M [00:00<01:10, 223kiB/s]
#
# Descargando modulo_05_2024.zip:  80%|███████▉  | 13.3M/16.7M [00:24<00:03, 883kiB/s]
#
# Descargando modulo_05_2024.zip:  81%|████████  | 13.5M/16.7M [00:25<00:03, 970kiB/s]
# Descargando modulo_34_2024.zip:   1%|          | 172k/15.9M [00:00<01:10, 224kiB/s]
#
# Descargando modulo_05_2024.zip:  82%|████████▏ | 13.7M/16.7M [00:25<00:02, 1.18MiB/s]
#
# Descargando modulo_05_2024.zip:  83%|████████▎ | 13.9M/16.7M [00:25<00:01, 1.50MiB/s]
# Descargando modulo_34_2024.zip:   1%|▏         | 205k/15.9M [00:01<01:23, 188kiB/s]
#
# Descargando modulo_05_2024.zip:  84%|████████▍ | 14.1M/16.7M [00:25<00:01, 1.49MiB/s]
# Descargando modulo_34_2024.zip:   2%|▏         | 295k/15.9M [00:01<00:50, 309kiB/s]
#
# Descargando modulo_05_2024.zip:  85%|████████▌ | 14.3M/16.7M [00:25<00:01, 1.57MiB/s]
# 2025-10-29 19:31:42 | INFO     | enaho_downloader | Descarga completada: modulo_04_2024.zip (13.5 MB)
# Descargando modulo_34_2024.zip:   2%|▏         | 393k/15.9M [00:01<00:35, 442kiB/s]
#
# Descargando modulo_05_2024.zip:  87%|████████▋ | 14.5M/16.7M [00:25<00:01, 1.72MiB/s]
# Descargando modulo_34_2024.zip:   3%|▎         | 524k/15.9M [00:01<00:24, 624kiB/s]
#
# Descargando modulo_05_2024.zip:  88%|████████▊ | 14.7M/16.7M [00:25<00:01, 1.82MiB/s]
#
# Descargando modulo_05_2024.zip:  89%|████████▉ | 14.9M/16.7M [00:25<00:01, 1.55MiB/s]
#
# Descargando modulo_05_2024.zip:  90%|█████████ | 15.1M/16.7M [00:25<00:01, 1.46MiB/s]
#
# Descargando modulo_05_2024.zip:  91%|█████████▏| 15.3M/16.7M [00:26<00:00, 1.59MiB/s]
# Descargando modulo_34_2024.zip:   4%|▍         | 606k/15.9M [00:01<00:44, 343kiB/s]
#
# Descargando modulo_05_2024.zip:  93%|█████████▎| 15.5M/16.7M [00:26<00:00, 1.67MiB/s]
#
# Descargando modulo_05_2024.zip:  94%|█████████▍| 15.7M/16.7M [00:26<00:00, 1.74MiB/s]
# Descargando modulo_34_2024.zip:   5%|▍         | 770k/15.9M [00:02<00:28, 524kiB/s]
# 2025-10-29 19:31:43 | INFO     | enaho_downloader | Extraídos 1 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_04_2024
# 2025-10-29 19:31:43 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_04_2024.zip
# Descargando modulo_05_2024.zip:  95%|█████████▍| 15.9M/16.7M [00:26<00:00, 1.77MiB/s]
# Descargando modulo_34_2024.zip:   6%|▌         | 934k/15.9M [00:02<00:21, 699kiB/s]
# Descargando modulo_34_2024.zip:   7%|▋         | 1.05M/15.9M [00:02<00:19, 755kiB/s]
#
# Descargando modulo_05_2024.zip:  96%|█████████▌| 16.1M/16.7M [00:26<00:00, 1.52MiB/s]
# Descargando modulo_34_2024.zip:   8%|▊         | 1.23M/15.9M [00:02<00:15, 969kiB/s]
#
# Descargando modulo_05_2024.zip:  97%|█████████▋| 16.2M/16.7M [00:26<00:00, 1.43MiB/s]
# Descargando modulo_34_2024.zip:   8%|▊         | 1.35M/15.9M [00:02<00:14, 999kiB/s]
#
# Descargando modulo_05_2024.zip:  98%|█████████▊| 16.4M/16.7M [00:26<00:00, 1.44MiB/s]
# Descargando modulo_34_2024.zip:   9%|▉         | 1.50M/15.9M [00:02<00:13, 1.11MiB/s]
#
# Descargando modulo_05_2024.zip:  99%|█████████▉| 16.5M/16.7M [00:26<00:00, 1.40MiB/s]
# Descargando modulo_34_2024.zip:  10%|█         | 1.63M/15.9M [00:02<00:12, 1.15MiB/s]
#
# Descargando modulo_05_2024.zip: 100%|██████████| 16.7M/16.7M [00:27<00:00, 618kiB/s]
#
# Descargando modulo_34_2024.zip:  11%|█         | 1.76M/15.9M [00:02<00:15, 918kiB/s]
# Descargando modulo_34_2024.zip:  12%|█▏        | 1.92M/15.9M [00:03<00:13, 1.06MiB/s]
# Descargando modulo_34_2024.zip:  13%|█▎        | 2.04M/15.9M [00:03<00:12, 1.09MiB/s]
# Descargando modulo_34_2024.zip:  14%|█▍        | 2.24M/15.9M [00:03<00:13, 998kiB/s]
# Descargando modulo_34_2024.zip:  15%|█▍        | 2.37M/15.9M [00:03<00:13, 1.04MiB/s]
# Descargando modulo_34_2024.zip:  16%|█▌        | 2.54M/15.9M [00:03<00:11, 1.19MiB/s]
# Descargando modulo_34_2024.zip:  17%|█▋        | 2.67M/15.9M [00:03<00:11, 1.20MiB/s]
# Descargando modulo_34_2024.zip:  18%|█▊        | 2.80M/15.9M [00:04<00:33, 398kiB/s]
# Descargando modulo_34_2024.zip:  18%|█▊        | 2.90M/15.9M [00:14<05:20, 40.7kiB/s]
# Descargando modulo_34_2024.zip:  19%|█▊        | 2.97M/15.9M [00:15<04:34, 47.2kiB/s]
# Descargando modulo_34_2024.zip:  19%|█▉        | 3.03M/15.9M [00:15<04:03, 53.0kiB/s]
# Descargando modulo_34_2024.zip:  21%|██        | 3.34M/15.9M [00:15<01:42, 123kiB/s]
# Descargando modulo_34_2024.zip:  22%|██▏       | 3.45M/15.9M [00:15<01:22, 151kiB/s]
# Descargando modulo_34_2024.zip:  23%|██▎       | 3.70M/15.9M [00:15<00:48, 254kiB/s]
# Descargando modulo_34_2024.zip:  25%|██▍       | 3.92M/15.9M [00:15<00:33, 362kiB/s]
# Descargando modulo_34_2024.zip:  26%|██▌       | 4.10M/15.9M [00:15<00:25, 468kiB/s]
# Descargando modulo_34_2024.zip:  27%|██▋       | 4.26M/15.9M [00:17<00:53, 220kiB/s]
# Descargando modulo_34_2024.zip:  28%|██▊       | 4.44M/15.9M [00:18<00:47, 242kiB/s]
# Descargando modulo_34_2024.zip:  29%|██▊       | 4.57M/15.9M [00:18<00:37, 300kiB/s]
# Descargando modulo_34_2024.zip:  29%|██▉       | 4.69M/15.9M [00:18<00:31, 355kiB/s]
# Descargando modulo_34_2024.zip:  30%|███       | 4.79M/15.9M [00:18<00:28, 396kiB/s]
# Descargando modulo_34_2024.zip:  31%|███       | 4.88M/15.9M [00:18<00:27, 399kiB/s]
# Descargando modulo_34_2024.zip:  31%|███       | 4.96M/15.9M [00:19<00:25, 436kiB/s]
# Descargando modulo_34_2024.zip:  32%|███▏      | 5.04M/15.9M [00:19<00:25, 427kiB/s]
# Descargando modulo_34_2024.zip:  32%|███▏      | 5.10M/15.9M [00:19<00:26, 406kiB/s]
# Descargando modulo_34_2024.zip:  32%|███▏      | 5.16M/15.9M [00:19<00:29, 367kiB/s]
# 2025-10-29 19:32:00 | INFO     | enaho_downloader | Descarga completada: modulo_05_2024.zip (15.9 MB)
# Descargando modulo_34_2024.zip:  33%|███▎      | 5.21M/15.9M [00:19<00:34, 313kiB/s]
# Descargando modulo_34_2024.zip:  33%|███▎      | 5.25M/15.9M [00:19<00:32, 326kiB/s]
# Descargando modulo_34_2024.zip:  33%|███▎      | 5.29M/15.9M [00:20<00:36, 289kiB/s]
# Descargando modulo_34_2024.zip:  33%|███▎      | 5.33M/15.9M [00:20<00:36, 290kiB/s]
# Descargando modulo_34_2024.zip:  34%|███▍      | 5.44M/15.9M [00:20<00:25, 412kiB/s]
# Descargando modulo_34_2024.zip:  34%|███▍      | 5.49M/15.9M [00:20<00:26, 395kiB/s]
# Descargando modulo_34_2024.zip:  35%|███▍      | 5.54M/15.9M [00:20<00:27, 378kiB/s]
# Descargando modulo_34_2024.zip:  35%|███▌      | 5.59M/15.9M [00:20<00:25, 399kiB/s]
# Descargando modulo_34_2024.zip:  35%|███▌      | 5.64M/15.9M [00:21<00:28, 360kiB/s]
# Descargando modulo_34_2024.zip:  36%|███▌      | 5.69M/15.9M [00:21<00:26, 387kiB/s]
# Descargando modulo_34_2024.zip:  36%|███▌      | 5.73M/15.9M [00:21<00:26, 383kiB/s]
# Descargando modulo_34_2024.zip:  36%|███▌      | 5.77M/15.9M [00:21<00:28, 363kiB/s]
# Descargando modulo_34_2024.zip:  36%|███▋      | 5.82M/15.9M [00:21<00:27, 372kiB/s]
# Descargando modulo_34_2024.zip:  37%|███▋      | 5.86M/15.9M [00:21<00:27, 367kiB/s]
# Descargando modulo_34_2024.zip:  37%|███▋      | 5.90M/15.9M [00:21<00:27, 361kiB/s]
# Descargando modulo_34_2024.zip:  37%|███▋      | 5.94M/15.9M [00:21<00:27, 358kiB/s]
# Descargando modulo_34_2024.zip:  38%|███▊      | 6.00M/15.9M [00:21<00:23, 431kiB/s]
# Descargando modulo_34_2024.zip:  38%|███▊      | 6.05M/15.9M [00:22<00:22, 441kiB/s]
# Descargando modulo_34_2024.zip:  38%|███▊      | 6.10M/15.9M [00:22<00:22, 435kiB/s]
# Descargando modulo_34_2024.zip:  39%|███▊      | 6.15M/15.9M [00:22<00:26, 375kiB/s]
# Descargando modulo_34_2024.zip:  39%|███▉      | 6.21M/15.9M [00:22<00:23, 421kiB/s]
# Descargando modulo_34_2024.zip:  39%|███▉      | 6.26M/15.9M [00:22<00:24, 402kiB/s]
# Descargando modulo_34_2024.zip:  40%|███▉      | 6.31M/15.9M [00:22<00:23, 416kiB/s]
# Descargando modulo_34_2024.zip:  40%|███▉      | 6.36M/15.9M [00:22<00:25, 383kiB/s]
# Descargando modulo_34_2024.zip:  40%|████      | 6.41M/15.9M [00:22<00:23, 401kiB/s]
# Descargando modulo_34_2024.zip:  41%|████      | 6.46M/15.9M [00:23<00:22, 412kiB/s]
# Descargando modulo_34_2024.zip:  41%|████      | 6.50M/15.9M [00:23<00:22, 424kiB/s]
# Descargando modulo_34_2024.zip:  41%|████      | 6.55M/15.9M [00:23<00:24, 377kiB/s]
# Descargando modulo_34_2024.zip:  41%|████▏     | 6.59M/15.9M [00:23<00:28, 333kiB/s]
# Descargando modulo_34_2024.zip:  42%|████▏     | 6.64M/15.9M [00:23<00:30, 310kiB/s]
# Descargando modulo_34_2024.zip:  42%|████▏     | 6.67M/15.9M [00:23<00:30, 299kiB/s]
# Descargando modulo_34_2024.zip:  42%|████▏     | 6.70M/15.9M [00:23<00:31, 297kiB/s]
# Descargando modulo_34_2024.zip:  42%|████▏     | 6.73M/15.9M [00:24<00:33, 278kiB/s]
# Descargando modulo_34_2024.zip:  43%|████▎     | 6.79M/15.9M [00:24<00:27, 331kiB/s]
# Descargando modulo_34_2024.zip:  43%|████▎     | 6.85M/15.9M [00:24<00:23, 382kiB/s]
# Descargando modulo_34_2024.zip:  44%|████▎     | 6.94M/15.9M [00:24<00:17, 502kiB/s]
# Descargando modulo_34_2024.zip:  44%|████▍     | 7.00M/15.9M [00:24<00:21, 426kiB/s]
# Descargando modulo_34_2024.zip:  44%|████▍     | 7.05M/15.9M [00:24<00:22, 391kiB/s]
# Descargando modulo_34_2024.zip:  45%|████▍     | 7.09M/15.9M [00:24<00:24, 356kiB/s]
# Descargando modulo_34_2024.zip:  45%|████▍     | 7.14M/15.9M [00:25<00:28, 307kiB/s]
# Descargando modulo_34_2024.zip:  45%|████▌     | 7.18M/15.9M [00:25<00:29, 295kiB/s]
# Descargando modulo_34_2024.zip:  45%|████▌     | 7.22M/15.9M [00:25<00:27, 313kiB/s]
# Descargando modulo_34_2024.zip:  46%|████▌     | 7.26M/15.9M [00:25<00:29, 298kiB/s]
# Descargando modulo_34_2024.zip:  46%|████▌     | 7.31M/15.9M [00:25<00:26, 324kiB/s]
# Descargando modulo_34_2024.zip:  46%|████▌     | 7.36M/15.9M [00:25<00:24, 358kiB/s]
# Descargando modulo_34_2024.zip:  46%|████▋     | 7.40M/15.9M [00:25<00:24, 352kiB/s]
# Descargando modulo_34_2024.zip:  47%|████▋     | 7.44M/15.9M [00:26<00:26, 323kiB/s]
# Descargando modulo_34_2024.zip:  47%|████▋     | 7.48M/15.9M [00:26<00:28, 297kiB/s]
# Descargando modulo_34_2024.zip:  47%|████▋     | 7.51M/15.9M [00:26<00:28, 301kiB/s]
# Descargando modulo_34_2024.zip:  47%|████▋     | 7.54M/15.9M [00:26<00:27, 301kiB/s]
# Descargando modulo_34_2024.zip:  48%|████▊     | 7.58M/15.9M [00:26<00:30, 271kiB/s]
# Descargando modulo_34_2024.zip:  48%|████▊     | 7.61M/15.9M [00:26<00:29, 281kiB/s]
# Descargando modulo_34_2024.zip:  48%|████▊     | 7.64M/15.9M [00:26<00:28, 289kiB/s]
# Descargando modulo_34_2024.zip:  48%|████▊     | 7.69M/15.9M [00:26<00:24, 330kiB/s]
# Descargando modulo_34_2024.zip:  49%|████▊     | 7.73M/15.9M [00:26<00:23, 346kiB/s]
# Descargando modulo_34_2024.zip:  49%|████▉     | 7.77M/15.9M [00:27<00:22, 357kiB/s]
# Descargando modulo_34_2024.zip:  49%|████▉     | 7.82M/15.9M [00:27<00:25, 321kiB/s]
# Descargando modulo_34_2024.zip:  49%|████▉     | 7.86M/15.9M [00:27<00:24, 329kiB/s]
# Descargando modulo_34_2024.zip:  50%|████▉     | 7.90M/15.9M [00:27<00:23, 335kiB/s]
# Descargando modulo_34_2024.zip:  50%|████▉     | 7.95M/15.9M [00:27<00:20, 391kiB/s]
# Descargando modulo_34_2024.zip:  50%|█████     | 8.00M/15.9M [00:27<00:21, 370kiB/s]
# Descargando modulo_34_2024.zip:  50%|█████     | 8.04M/15.9M [00:27<00:23, 336kiB/s]
# Descargando modulo_34_2024.zip:  51%|█████     | 8.09M/15.9M [00:27<00:20, 390kiB/s]
# Descargando modulo_34_2024.zip:  51%|█████     | 8.13M/15.9M [00:28<00:20, 386kiB/s]
# Descargando modulo_34_2024.zip:  51%|█████▏    | 8.18M/15.9M [00:28<00:20, 376kiB/s]
# Descargando modulo_34_2024.zip:  52%|█████▏    | 8.22M/15.9M [00:28<00:20, 376kiB/s]
# Descargando modulo_34_2024.zip:  52%|█████▏    | 8.26M/15.9M [00:28<00:22, 347kiB/s]
# Descargando modulo_34_2024.zip:  52%|█████▏    | 8.30M/15.9M [00:28<00:21, 350kiB/s]
# Descargando modulo_34_2024.zip:  52%|█████▏    | 8.34M/15.9M [00:28<00:21, 360kiB/s]
# Descargando modulo_34_2024.zip:  53%|█████▎    | 8.38M/15.9M [00:28<00:23, 327kiB/s]
# Descargando modulo_34_2024.zip:  53%|█████▎    | 8.42M/15.9M [00:28<00:22, 337kiB/s]
# Descargando modulo_34_2024.zip:  53%|█████▎    | 8.46M/15.9M [00:29<00:24, 311kiB/s]
# Descargando modulo_34_2024.zip:  53%|█████▎    | 8.50M/15.9M [00:29<00:26, 281kiB/s]
# Descargando modulo_34_2024.zip:  54%|█████▎    | 8.53M/15.9M [00:29<00:25, 289kiB/s]
# Descargando modulo_34_2024.zip:  54%|█████▎    | 8.56M/15.9M [00:29<00:26, 283kiB/s]
# Descargando modulo_34_2024.zip:  54%|█████▍    | 8.59M/15.9M [00:29<00:25, 289kiB/s]
# Descargando modulo_34_2024.zip:  54%|█████▍    | 8.63M/15.9M [00:29<00:25, 286kiB/s]
# Descargando modulo_34_2024.zip:  54%|█████▍    | 8.68M/15.9M [00:29<00:21, 338kiB/s]
# Descargando modulo_34_2024.zip:  55%|█████▍    | 8.72M/15.9M [00:29<00:24, 292kiB/s]
# Descargando modulo_34_2024.zip:  55%|█████▍    | 8.76M/15.9M [00:30<00:27, 264kiB/s]
# Descargando modulo_34_2024.zip:  55%|█████▌    | 8.79M/15.9M [00:30<00:28, 255kiB/s]
# Descargando modulo_34_2024.zip:  56%|█████▌    | 8.85M/15.9M [00:30<00:22, 313kiB/s]
# Descargando modulo_34_2024.zip:  56%|█████▌    | 8.88M/15.9M [00:30<00:22, 316kiB/s]
# Descargando modulo_34_2024.zip:  56%|█████▌    | 8.91M/15.9M [00:30<00:23, 303kiB/s]
# Descargando modulo_34_2024.zip:  56%|█████▌    | 8.95M/15.9M [00:30<00:23, 299kiB/s]
# Descargando modulo_34_2024.zip:  56%|█████▋    | 8.98M/15.9M [00:30<00:24, 287kiB/s]
# Descargando modulo_34_2024.zip:  57%|█████▋    | 9.01M/15.9M [00:30<00:23, 292kiB/s]
# Descargando modulo_34_2024.zip:  57%|█████▋    | 9.04M/15.9M [00:31<00:25, 269kiB/s]
# Descargando modulo_34_2024.zip:  57%|█████▋    | 9.08M/15.9M [00:31<00:25, 265kiB/s]
# Descargando modulo_34_2024.zip:  57%|█████▋    | 9.13M/15.9M [00:31<00:22, 309kiB/s]
# Descargando modulo_34_2024.zip:  58%|█████▊    | 9.21M/15.9M [00:31<00:15, 431kiB/s]
# Descargando modulo_34_2024.zip:  59%|█████▉    | 9.40M/15.9M [00:31<00:08, 813kiB/s]
# Descargando modulo_34_2024.zip:  60%|█████▉    | 9.49M/15.9M [00:31<00:08, 759kiB/s]
# Descargando modulo_34_2024.zip:  60%|██████    | 9.58M/15.9M [00:31<00:10, 611kiB/s]
# Descargando modulo_34_2024.zip:  61%|██████    | 9.65M/15.9M [00:32<00:11, 548kiB/s]
# 2025-10-29 19:32:13 | INFO     | enaho_downloader | Extraídos 5 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_05_2024
# Descargando modulo_34_2024.zip:  61%|██████    | 9.72M/15.9M [00:32<00:12, 503kiB/s]
# 2025-10-29 19:32:13 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_05_2024.zip
# Descargando modulo_34_2024.zip:  61%|██████▏   | 9.77M/15.9M [00:32<00:12, 487kiB/s]
# Descargando modulo_34_2024.zip:  62%|██████▏   | 9.83M/15.9M [00:32<00:13, 438kiB/s]
# Descargando modulo_34_2024.zip:  62%|██████▏   | 9.88M/15.9M [00:32<00:13, 445kiB/s]
# Descargando modulo_34_2024.zip:  62%|██████▏   | 9.96M/15.9M [00:32<00:11, 528kiB/s]
# Descargando modulo_34_2024.zip:  63%|██████▎   | 10.1M/15.9M [00:32<00:08, 667kiB/s]
# Descargando modulo_34_2024.zip:  64%|██████▎   | 10.2M/15.9M [00:32<00:08, 665kiB/s]
# Descargando modulo_34_2024.zip:  64%|██████▍   | 10.2M/15.9M [00:33<00:08, 648kiB/s]
# Descargando modulo_34_2024.zip:  65%|██████▍   | 10.3M/15.9M [00:33<00:08, 677kiB/s]
# Descargando modulo_34_2024.zip:  65%|██████▌   | 10.4M/15.9M [00:33<00:07, 756kiB/s]
# Descargando modulo_34_2024.zip:  66%|██████▌   | 10.5M/15.9M [00:33<00:07, 751kiB/s]
# Descargando modulo_34_2024.zip:  66%|██████▋   | 10.6M/15.9M [00:33<00:07, 696kiB/s]
# Descargando modulo_34_2024.zip:  67%|██████▋   | 10.7M/15.9M [00:33<00:09, 555kiB/s]
# Descargando modulo_34_2024.zip:  67%|██████▋   | 10.7M/15.9M [00:33<00:11, 465kiB/s]
# Descargando modulo_34_2024.zip:  68%|██████▊   | 10.8M/15.9M [00:34<00:12, 413kiB/s]
# Descargando modulo_34_2024.zip:  68%|██████▊   | 10.9M/15.9M [00:34<00:10, 477kiB/s]
# Descargando modulo_34_2024.zip:  69%|██████▊   | 10.9M/15.9M [00:34<00:11, 430kiB/s]
# Descargando modulo_34_2024.zip:  69%|██████▉   | 11.0M/15.9M [00:34<00:12, 384kiB/s]
# Descargando modulo_34_2024.zip:  69%|██████▉   | 11.0M/15.9M [00:34<00:11, 421kiB/s]
# Descargando modulo_34_2024.zip:  69%|██████▉   | 11.1M/15.9M [00:34<00:13, 372kiB/s]
# Descargando modulo_34_2024.zip:  70%|██████▉   | 11.1M/15.9M [00:35<00:13, 353kiB/s]
# Descargando modulo_34_2024.zip:  70%|███████   | 11.2M/15.9M [00:35<00:12, 385kiB/s]
# Descargando modulo_34_2024.zip:  71%|███████   | 11.3M/15.9M [00:35<00:10, 468kiB/s]
# Descargando modulo_34_2024.zip:  71%|███████   | 11.3M/15.9M [00:35<00:10, 442kiB/s]
# Descargando modulo_34_2024.zip:  71%|███████▏  | 11.4M/15.9M [00:35<00:11, 412kiB/s]
# Descargando modulo_34_2024.zip:  72%|███████▏  | 11.4M/15.9M [00:35<00:12, 361kiB/s]
# Descargando modulo_34_2024.zip:  72%|███████▏  | 11.5M/15.9M [00:35<00:14, 315kiB/s]
# Descargando modulo_34_2024.zip:  72%|███████▏  | 11.5M/15.9M [00:36<00:14, 306kiB/s]
# Descargando modulo_34_2024.zip:  72%|███████▏  | 11.5M/15.9M [00:36<00:16, 260kiB/s]
# Descargando modulo_34_2024.zip:  73%|███████▎  | 11.6M/15.9M [00:36<00:16, 262kiB/s]
# Descargando modulo_34_2024.zip:  73%|███████▎  | 11.6M/15.9M [00:36<00:15, 274kiB/s]
# Descargando modulo_34_2024.zip:  73%|███████▎  | 11.7M/15.9M [00:36<00:11, 364kiB/s]
# Descargando modulo_34_2024.zip:  73%|███████▎  | 11.7M/15.9M [00:36<00:12, 348kiB/s]
# Descargando modulo_34_2024.zip:  74%|███████▎  | 11.7M/15.9M [00:36<00:11, 352kiB/s]
# Descargando modulo_34_2024.zip:  74%|███████▍  | 11.8M/15.9M [00:36<00:10, 385kiB/s]
# Descargando modulo_34_2024.zip:  74%|███████▍  | 11.8M/15.9M [00:37<00:10, 388kiB/s]
# Descargando modulo_34_2024.zip:  74%|███████▍  | 11.9M/15.9M [00:37<00:18, 226kiB/s]
# Descargando modulo_34_2024.zip:  76%|███████▌  | 12.0M/15.9M [00:37<00:07, 491kiB/s]
# Descargando modulo_34_2024.zip:  76%|███████▋  | 12.2M/15.9M [00:37<00:05, 672kiB/s]
# Descargando modulo_34_2024.zip:  77%|███████▋  | 12.3M/15.9M [00:37<00:04, 786kiB/s]
# Descargando modulo_34_2024.zip:  78%|███████▊  | 12.5M/15.9M [00:37<00:03, 1.04MiB/s]
# Descargando modulo_34_2024.zip:  79%|███████▉  | 12.6M/15.9M [00:37<00:02, 1.14MiB/s]
# Descargando modulo_34_2024.zip:  81%|████████  | 12.8M/15.9M [00:38<00:02, 1.35MiB/s]
# Descargando modulo_34_2024.zip:  82%|████████▏ | 13.1M/15.9M [00:38<00:01, 1.58MiB/s]
# Descargando modulo_34_2024.zip:  84%|████████▎ | 13.3M/15.9M [00:38<00:01, 1.79MiB/s]
# Descargando modulo_34_2024.zip:  85%|████████▍ | 13.5M/15.9M [00:38<00:03, 712kiB/s]
# Descargando modulo_34_2024.zip:  86%|████████▌ | 13.7M/15.9M [00:54<00:56, 39.7kiB/s]
# Descargando modulo_34_2024.zip:  86%|████████▌ | 13.7M/15.9M [00:54<00:56, 39.9kiB/s]
# Descargando modulo_34_2024.zip:  87%|████████▋ | 13.8M/15.9M [00:54<00:42, 50.1kiB/s]
# Descargando modulo_34_2024.zip:  87%|████████▋ | 13.9M/15.9M [00:55<00:34, 59.5kiB/s]
# Descargando modulo_34_2024.zip:  87%|████████▋ | 13.9M/15.9M [00:55<00:30, 65.8kiB/s]
# Descargando modulo_34_2024.zip:  88%|████████▊ | 14.0M/15.9M [00:56<00:25, 75.5kiB/s]
# Descargando modulo_34_2024.zip:  89%|████████▊ | 14.1M/15.9M [00:56<00:14, 124kiB/s]
# Descargando modulo_34_2024.zip:  90%|████████▉ | 14.3M/15.9M [00:56<00:08, 187kiB/s]
# Descargando modulo_34_2024.zip:  91%|█████████ | 14.4M/15.9M [00:56<00:05, 269kiB/s]
# Descargando modulo_34_2024.zip:  92%|█████████▏| 14.7M/15.9M [00:56<00:02, 455kiB/s]
# Descargando modulo_34_2024.zip:  94%|█████████▍| 15.0M/15.9M [00:56<00:01, 678kiB/s]
# Descargando modulo_34_2024.zip:  95%|█████████▌| 15.2M/15.9M [01:00<00:01, 515kiB/s]
# Descargando modulo_34_2024.zip:  96%|█████████▌| 15.3M/15.9M [01:00<00:03, 167kiB/s]
# Descargando modulo_34_2024.zip:  97%|█████████▋| 15.4M/15.9M [01:00<00:03, 157kiB/s]
# Descargando modulo_34_2024.zip:  98%|█████████▊| 15.6M/15.9M [01:01<00:01, 217kiB/s]
# Descargando modulo_34_2024.zip:  98%|█████████▊| 15.7M/15.9M [01:01<00:01, 241kiB/s]
# Descargando modulo_34_2024.zip:  99%|█████████▉| 15.8M/15.9M [01:01<00:00, 270kiB/s]
# Descargando modulo_34_2024.zip:  99%|█████████▉| 15.8M/15.9M [01:01<00:00, 315kiB/s]
# Descargando modulo_34_2024.zip: 100%|██████████| 15.9M/15.9M [01:01<00:00, 258kiB/s]
# 2025-10-29 19:32:46 | INFO     | enaho_downloader | Descarga completada: modulo_34_2024.zip (15.2 MB)
# 2025-10-29 19:32:51 | INFO     | enaho_downloader | Extraídos 2 archivos en: E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_34_2024
# 2025-10-29 19:32:51 | INFO     | enaho_downloader | Archivo ZIP eliminado: modulo_34_2024.zip
# 2025-10-29 19:33:08 | INFO     | enaho_downloader | Archivo cargado: sumaria-2024-12g.dta (33691 filas)
# 2025-10-29 19:33:11 | INFO     | enaho_downloader | Archivo cargado: enaho01a-2024-400.dta (110451 filas)
# 2025-10-29 19:33:17 | INFO     | enaho_downloader | Archivo cargado: sumaria-2024.dta (33691 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Archivo cargado: enaho01a-2024-500.dta (85992 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_ciiu_rev3.dta (296 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_ciiu_rev4.dta (419 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_ciuo_88.dta (5195 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Archivo cargado: enaho_tabla_cno_2015.dta (473 filas)
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | === Resumen de descarga ===
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Tareas completadas: 6/6
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Tasa de éxito: 100.0%
# 2025-10-29 19:33:22 | INFO     | enaho_downloader | Tiempo total: 165.4 segundos
# 2025-10-29 19:33:22 | DEBUG    | enahopy.loader.core.cache | Cache updated for key: last_download_session
# 2025-10-29 19:33:22 | INFO     | enahopy.performance.enahopy.loader.io.main.download | Function download executed in 165.3745s
#
# ✓ Descarga completada
# Extrayendo datasets...
#   hogar: 44,731 filas × 12 columnas
#   persona: 117,721 filas × 9 columnas
#   educacion: 106,619 filas × 8 columnas
#   salud: 110,451 filas × 21 columnas
#   empleo: 85,992 filas × 21 columnas
#   sumaria: 33,691 filas × 13 columnas
#
# ======================================================================
#                 PASO 1: FUSIÓN DE MÓDULOS INDIVIDUALES
# ======================================================================
#
# Fusionando datos individuales (persona + educación + salud + empleo)...
#
# 📦 Usando ENAHOModuleMerger de enahopy para fusionar módulos 02, 03, 04, 05...
#
# ✓ Módulos individuales fusionados: (117721, 47)
#
# 📦 Usando ENAHOModuleMerger de enahopy para fusionar sumaria con caracteristicas del hogar...
#
# ✓ Módulos a nivel Hogares fusionados: (33691, 22)

# %%
from analisis_pob_mon_lab import pipeline_completo, analisis_descriptivo_ponderado


df_final = pipeline_completo(
      df_individuos=data_individuos,
      df_hogares_enaho=data_hogares,
      ruta_ciiu=r'E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_05_2024\enaho_tabla_ciiu_rev4.dta',
      ruta_cno=r'E:\papx\end_to_end_ml\nb_pr\enahopy\examples\investigacion\data\modulo_05_2024\enaho_tabla_cno_2015.dta'
  )
#
# resultados = analisis_descriptivo_ponderado(
#     df=df_final,
#     var_pobreza='es_pobre_monetario',
#     peso='factor07'
# )
# Out:
# ================================================================================
# INICIANDO PIPELINE COMPLETO DE PROCESAMIENTO
# ================================================================================
#
# → Cargando tablas CIIU y CNO...
#   ✓ CIIU: 52 códigos cargados
#   ✓ CNO: 46 códigos cargados
#
# → Limpiando variables individuales...
#   ✓ p208a: 113755 valores válidos
#   ✓ p513t: 62874 valores válidos
#   ✓ i524e1: 25327 valores válidos
#   ✓ p301b: 100072 valores válidos
#   ✓ p301c: 23740 valores válidos
#
# → Creando características individuales...
#   • Calculando informalidad laboral...
#     ✓ 43078/61878 informales (69.6%)
#   • Identificando personas con discapacidad...
#     ✓ 6,052 personas con discapacidad (5.1%)
#   • Identificando personas con seguro de salud...
#     ✓ Encontradas 8 columnas de seguro: p4191, p4192, p4193, p4194, p4195, p4196, p4197, p4198
#     DEBUG - Valores únicos en p4191:
#                  'no' :   85,929 ( 73.0%)
#             'essalud' :   24,422 ( 20.7%)
#                   nan :    7,370 (  6.3%)
#       • essalud: 24,422 personas (20.7%)
#       • seguro_privado: 1,070 personas (0.9%)
#       • entidad_prestadora: 753 personas (0.6%)
#       • seguro_ffaa_policial: 1,029 personas (0.9%)
#       • sis: 74,747 personas (63.5%)
#       • seguro_universitario: 326 personas (0.3%)
#       • seguro_escolar_privado: 9 personas (0.0%)
#       • otro_seguro: 358 personas (0.3%)
#     ✓ TOTAL con al menos un seguro: 101,127 personas (85.9%)
#   • Clasificando grupos etarios...
#     ✓ Niños: 25225, Edad trabajar: 74442, Adultos mayores: 14088
#   • Calculando años de escolaridad...
#     ✓ Media: 8.4 años
#
# → Extrayendo características del Jefe de Hogar...
#   ✓ 33691 jefes de hogar identificados
#   Distribución educación jefes:
# {'Media': 12746, 'Baja': 12377, 'Alta': 8563}
#   • Clasificando ocupación del jefe de hogar...
#     ✓ Ocupaciones clasificadas
#   • Clasificando sector económico del jefe de hogar...
#     ✓ Sectores clasificados
#
# → Agregando características a nivel de hogar...
#   ✓ Hogares únicos: 33691
#   ✓ Columnas en dataset agregado: 27
#
# → Agregando características de vivienda...
#   ✓ Merge completado: 33691 registros
#
# → Calculando ratios y tasas a nivel hogar...
#   ✓ Ratio dependencia promedio: 0.55
#   ✓ Tasa informalidad promedio: 72.9%
#   ✓ Proporción asegurados promedio: 86.9%
#
# → Calculando variables objetivo (Y1, Y2)...
#   ✓ Pobreza monetaria: 6812 hogares (20.2%)
#   ✓ Pobreza laboral: 16352 hogares (48.5%)
#
# ================================================================================
# PIPELINE COMPLETADO
# Dataset final: 33691 hogares × 68 variables
# ================================================================================

# %%
df_final.sample(15)
# Out:
#       conglome vivienda hogar  n_personas  n_ninos  n_adultos_mayores  \
# 14368   017278      388    11           4        0                  0
# 30826   020126      062    22           3        1                  0
# 11788   016849      028    11           3        1                  0
# 14783   017335      111    11           4        0                  1
# 8518    016358      074    11           4        0                  0
# 20316   018324      044    11           4        1                  0
# 438     015078      047    11           7        3                  0
# 19517   018152      131    11           2        0                  0
# 21133   018477      020    11           8        0                  0
# 238     015042      140    11           5        2                  0
# 1812    015288      026    11           3        0                  0
# 867     015139      286    11           3        1                  0
# 22857   018770      053    11           6        1                  0
# 807     015130      122    11           3        0                  0
# 31120   020177      003    11           5        2                  0
#
#        n_edad_trabajar  n_ocupados  n_informales  n_discapacitados  ...  \
# 14368                2           2           2.0                 0  ...
# 30826                2           1           1.0                 0  ...
# 11788                2           1           0.0                 0  ...
# 14783                3           2           0.0                 1  ...
# 8518                 4           3           2.0                 0  ...
# 20316                3           1           0.0                 0  ...
# 438                  4           4           4.0                 0  ...
# 19517                2           2           1.0                 0  ...
# 21133                6           3           1.0                 0  ...
# 238                  3           1           1.0                 0  ...
# 1812                 3           2           1.0                 0  ...
# 867                  2           2           2.0                 0  ...
# 22857                5           1           1.0                 0  ...
# 807                  3           3           3.0                 0  ...
# 31120                3           2           2.0                 0  ...
#
#        tasa_informalidad_hogar  prop_asegurados  prop_discapacitados  \
# 14368                 1.000000         0.250000                 0.00
# 30826                 1.000000         1.000000                 0.00
# 11788                 0.000000         0.666667                 0.00
# 14783                 0.000000         1.000000                 0.25
# 8518                  0.666667         1.000000                 0.00
# 20316                 0.000000         1.000000                 0.00
# 438                   1.000000         1.000000                 0.00
# 19517                 0.500000         0.500000                 0.00
# 21133                 0.333333         0.500000                 0.00
# 238                   1.000000         0.800000                 0.00
# 1812                  0.500000         0.666667                 0.00
# 867                   1.000000         1.000000                 0.00
# 22857                 1.000000         1.000000                 0.00
# 807                   1.000000         1.000000                 0.00
# 31120                 1.000000         1.000000                 0.00
#
#        ingreso_laboral_percapita  ingreso_por_hora carga_ninos  \
# 14368                   0.000000          0.000000    0.000000
# 30826                5341.666504         95.386905    0.333333
# 11788                3965.000000         61.953125    0.333333
# 14783               11943.750000        140.514706    0.000000
# 8518                16994.500000        124.959559    0.000000
# 20316                3911.750000         81.494792    0.250000
# 438                  5753.428711         71.407801    0.428571
# 19517               11306.500000         47.110417    0.000000
# 21133                5657.500000         72.532051    0.000000
# 238                  7467.200195        233.350000    0.400000
# 1812                 9506.333008         68.555288    0.000000
# 867                     0.000000          0.000000    0.333333
# 22857                   0.000000          0.000000    0.166667
# 807                  1078.333374          6.470000    0.000000
# 31120                   0.000000          0.000000    0.400000
#
#       carga_adultos_mayores ocupados_per_capita es_pobre_monetario  \
# 14368                  0.00            1.000000                  0
# 30826                  0.00            0.333333                  1
# 11788                  0.00            0.333333                  0
# 14783                  0.25            0.500000                  0
# 8518                   0.00            0.750000                  0
# 20316                  0.00            0.250000                  0
# 438                    0.00            0.571429                  0
# 19517                  0.00            1.000000                  0
# 21133                  0.00            0.500000                  0
# 238                    0.00            0.200000                  0
# 1812                   0.00            0.666667                  0
# 867                    0.00            0.666667                  1
# 22857                  0.00            0.166667                  1
# 807                    0.00            1.000000                  0
# 31120                  0.00            0.400000                  1
#
#       pobreza_laboral
# 14368               1
# 30826               0
# 11788               0
# 14783               0
# 8518                0
# 20316               0
# 438                 0
# 19517               0
# 21133               0
# 238                 0
# 1812                0
# 867                 1
# 22857               1
# 807                 0
# 31120               1
#
# [15 rows x 68 columns]

# %%
df_final.to_csv('dataframe_final_2024.csv', index=False)
